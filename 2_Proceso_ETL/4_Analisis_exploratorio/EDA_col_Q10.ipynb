# %% [markdown]
# # Análisis exploratorio y Limpieza

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import sidetable as stb
from sklearn.preprocessing import OneHotEncoder
import re

# %%
df10 = pd.read_csv("/home/adalaber/Escritorio/PROYECTO_2/1_Input/data.csv" , index_col= 0)
df10.head(2)
# Out:
#               Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# index
# 0                    NaN  Colab Notebooks        NaN        NaN        NaN
# 1       Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
#
#       Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10 Q10_Part_11  \
# index
# 0            NaN        NaN        NaN        NaN         NaN         NaN
# 1            NaN        NaN        NaN        NaN         NaN         NaN
#
#       Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15 Q10_Part_16 Q10_OTHER
# index
# 0             NaN         NaN         NaN         NaN         NaN       NaN
# 1             NaN         NaN         NaN         NaN         NaN       NaN

# %%
df10.describe()
# Out:
#                Q10_Part_1       Q10_Part_2       Q10_Part_3  \
# count                9507             9792             1062
# unique                  1                1                1
# top      Kaggle Notebooks  Colab Notebooks  Azure Notebooks
# freq                 9507             9792             1062
#
#                      Q10_Part_4             Q10_Part_5    Q10_Part_6  \
# count                       209                   1770           175
# unique                        1                      1             1
# top      Paperspace / Gradient    Binder / JupyterHub    Code Ocean
# freq                        209                   1770           175
#
#                  Q10_Part_7                           Q10_Part_8  \
# count                  1067                                  753
# unique                    1                                    1
# top      IBM Watson Studio    Amazon Sagemaker Studio Notebooks
# freq                   1067                                  753
#
#                     Q10_Part_9  \
# count                      348
# unique                       1
# top      Amazon EMR Notebooks
# freq                       348
#
#                                               Q10_Part_10  \
# count                                                2051
# unique                                                  1
# top     Google Cloud Notebooks (AI Platform / Vertex AI)
# freq                                                 2051
#
#                  Q10_Part_11                           Q10_Part_12  \
# count                   1794                                   590
# unique                     1                                     1
# top     Google Cloud Datalab   Databricks Collaborative Notebooks
# freq                    1794                                   590
#
#                         Q10_Part_13           Q10_Part_14  \
# count                           251                   260
# unique                            1                     1
# top      Zeppelin / Zepl Notebooks    Deepnote Notebooks
# freq                            251                   260
#
#                    Q10_Part_15 Q10_Part_16 Q10_OTHER
# count                      147        7174       737
# unique                       1           1         1
# top      Observable Notebooks         None     Other
# freq                       147        7174       737

# %%
#VALORES ÚNICOS
for col in df10:
    print(df10[col].unique())
# Out:
# [nan ' Kaggle Notebooks']
# ['Colab Notebooks' nan]
# [nan 'Azure Notebooks']
# [nan ' Paperspace / Gradient ']
# [nan ' Binder / JupyterHub ']
# [nan ' Code Ocean ']
# [nan ' IBM Watson Studio ']
# [nan ' Amazon Sagemaker Studio Notebooks ']
# [nan ' Amazon EMR Notebooks ']
# [nan 'Google Cloud Notebooks (AI Platform / Vertex AI) ']
# [nan 'Google Cloud Datalab']
# [nan ' Databricks Collaborative Notebooks ']
# [nan ' Zeppelin / Zepl Notebooks ']
# [nan ' Deepnote Notebooks ']
# [nan ' Observable Notebooks ']
# [nan 'None']
# [nan 'Other']

# %%
#PORCENTAJE DE NULOS
for col in df10:
    try: 
        print(df10[col].isnull().sum() / df10.shape[0] * 100)
    except:
        print("No puedo")
# Out:
# 63.39660416586456
# 62.2993108227775
# 95.91113848997036
# 99.19531821506949
# 93.18523081661726
# 99.32622338582374
# 95.89188772956531
# 97.10083548300157
# 98.66014707580949
# 92.10333808185423
# 93.09282716667309
# 97.72841027220576
# 99.03361182766719
# 98.99896045893813
# 99.43402764409194
# 72.37900897085436
# 97.16243791629769

# %% [markdown]
# - Con .describe() y los valores únicos, comprobamos que cada una de las columnas de Q10 corresponde a un desglose tipo encoding de Q10, donde cada una de las columnas corresponde a una herramienta de "notebook" usada por las personas encuestadas.
#
# - Al investigar los valores nulos, vemos que representan un % enorme de cada subcolumna.
#
# - En este sentido, la forma más sencilla de extraer información es realizar un conteo de los valores no nulos de cada subcolumna (equiparables a un sí/no de si se usa o no esa herramienta para cada usuario/fila), y así comprobar en qué medida las personas utilizan unas y/u otras herramientas.

# %%
lista = []
for col in df10:
    a = df10[col].value_counts()
    lista.append(a)

# %%
b = pd.DataFrame(lista)
b
# Out:
#               Kaggle Notebooks  Colab Notebooks  Azure Notebooks  \
# Q10_Part_1              9507.0              NaN              NaN
# Q10_Part_2                 NaN           9792.0              NaN
# Q10_Part_3                 NaN              NaN           1062.0
# Q10_Part_4                 NaN              NaN              NaN
# Q10_Part_5                 NaN              NaN              NaN
# Q10_Part_6                 NaN              NaN              NaN
# Q10_Part_7                 NaN              NaN              NaN
# Q10_Part_8                 NaN              NaN              NaN
# Q10_Part_9                 NaN              NaN              NaN
# Q10_Part_10                NaN              NaN              NaN
# Q10_Part_11                NaN              NaN              NaN
# Q10_Part_12                NaN              NaN              NaN
# Q10_Part_13                NaN              NaN              NaN
# Q10_Part_14                NaN              NaN              NaN
# Q10_Part_15                NaN              NaN              NaN
# Q10_Part_16                NaN              NaN              NaN
# Q10_OTHER                  NaN              NaN              NaN
#
#               Paperspace / Gradient    Binder / JupyterHub    Code Ocean   \
# Q10_Part_1                       NaN                    NaN           NaN
# Q10_Part_2                       NaN                    NaN           NaN
# Q10_Part_3                       NaN                    NaN           NaN
# Q10_Part_4                     209.0                    NaN           NaN
# Q10_Part_5                       NaN                 1770.0           NaN
# Q10_Part_6                       NaN                    NaN         175.0
# Q10_Part_7                       NaN                    NaN           NaN
# Q10_Part_8                       NaN                    NaN           NaN
# Q10_Part_9                       NaN                    NaN           NaN
# Q10_Part_10                      NaN                    NaN           NaN
# Q10_Part_11                      NaN                    NaN           NaN
# Q10_Part_12                      NaN                    NaN           NaN
# Q10_Part_13                      NaN                    NaN           NaN
# Q10_Part_14                      NaN                    NaN           NaN
# Q10_Part_15                      NaN                    NaN           NaN
# Q10_Part_16                      NaN                    NaN           NaN
# Q10_OTHER                        NaN                    NaN           NaN
#
#               IBM Watson Studio    Amazon Sagemaker Studio Notebooks   \
# Q10_Part_1                   NaN                                  NaN
# Q10_Part_2                   NaN                                  NaN
# Q10_Part_3                   NaN                                  NaN
# Q10_Part_4                   NaN                                  NaN
# Q10_Part_5                   NaN                                  NaN
# Q10_Part_6                   NaN                                  NaN
# Q10_Part_7                1067.0                                  NaN
# Q10_Part_8                   NaN                                753.0
# Q10_Part_9                   NaN                                  NaN
# Q10_Part_10                  NaN                                  NaN
# Q10_Part_11                  NaN                                  NaN
# Q10_Part_12                  NaN                                  NaN
# Q10_Part_13                  NaN                                  NaN
# Q10_Part_14                  NaN                                  NaN
# Q10_Part_15                  NaN                                  NaN
# Q10_Part_16                  NaN                                  NaN
# Q10_OTHER                    NaN                                  NaN
#
#               Amazon EMR Notebooks   \
# Q10_Part_1                      NaN
# Q10_Part_2                      NaN
# Q10_Part_3                      NaN
# Q10_Part_4                      NaN
# Q10_Part_5                      NaN
# Q10_Part_6                      NaN
# Q10_Part_7                      NaN
# Q10_Part_8                      NaN
# Q10_Part_9                    348.0
# Q10_Part_10                     NaN
# Q10_Part_11                     NaN
# Q10_Part_12                     NaN
# Q10_Part_13                     NaN
# Q10_Part_14                     NaN
# Q10_Part_15                     NaN
# Q10_Part_16                     NaN
# Q10_OTHER                       NaN
#
#              Google Cloud Notebooks (AI Platform / Vertex AI)   \
# Q10_Part_1                                                 NaN
# Q10_Part_2                                                 NaN
# Q10_Part_3                                                 NaN
# Q10_Part_4                                                 NaN
# Q10_Part_5                                                 NaN
# Q10_Part_6                                                 NaN
# Q10_Part_7                                                 NaN
# Q10_Part_8                                                 NaN
# Q10_Part_9                                                 NaN
# Q10_Part_10                                             2051.0
# Q10_Part_11                                                NaN
# Q10_Part_12                                                NaN
# Q10_Part_13                                                NaN
# Q10_Part_14                                                NaN
# Q10_Part_15                                                NaN
# Q10_Part_16                                                NaN
# Q10_OTHER                                                  NaN
#
#              Google Cloud Datalab   Databricks Collaborative Notebooks   \
# Q10_Part_1                    NaN                                   NaN
# Q10_Part_2                    NaN                                   NaN
# Q10_Part_3                    NaN                                   NaN
# Q10_Part_4                    NaN                                   NaN
# Q10_Part_5                    NaN                                   NaN
# Q10_Part_6                    NaN                                   NaN
# Q10_Part_7                    NaN                                   NaN
# Q10_Part_8                    NaN                                   NaN
# Q10_Part_9                    NaN                                   NaN
# Q10_Part_10                   NaN                                   NaN
# Q10_Part_11                1794.0                                   NaN
# Q10_Part_12                   NaN                                 590.0
# Q10_Part_13                   NaN                                   NaN
# Q10_Part_14                   NaN                                   NaN
# Q10_Part_15                   NaN                                   NaN
# Q10_Part_16                   NaN                                   NaN
# Q10_OTHER                     NaN                                   NaN
#
#               Zeppelin / Zepl Notebooks    Deepnote Notebooks   \
# Q10_Part_1                           NaN                   NaN
# Q10_Part_2                           NaN                   NaN
# Q10_Part_3                           NaN                   NaN
# Q10_Part_4                           NaN                   NaN
# Q10_Part_5                           NaN                   NaN
# Q10_Part_6                           NaN                   NaN
# Q10_Part_7                           NaN                   NaN
# Q10_Part_8                           NaN                   NaN
# Q10_Part_9                           NaN                   NaN
# Q10_Part_10                          NaN                   NaN
# Q10_Part_11                          NaN                   NaN
# Q10_Part_12                          NaN                   NaN
# Q10_Part_13                        251.0                   NaN
# Q10_Part_14                          NaN                 260.0
# Q10_Part_15                          NaN                   NaN
# Q10_Part_16                          NaN                   NaN
# Q10_OTHER                            NaN                   NaN
#
#               Observable Notebooks     None  Other
# Q10_Part_1                      NaN     NaN    NaN
# Q10_Part_2                      NaN     NaN    NaN
# Q10_Part_3                      NaN     NaN    NaN
# Q10_Part_4                      NaN     NaN    NaN
# Q10_Part_5                      NaN     NaN    NaN
# Q10_Part_6                      NaN     NaN    NaN
# Q10_Part_7                      NaN     NaN    NaN
# Q10_Part_8                      NaN     NaN    NaN
# Q10_Part_9                      NaN     NaN    NaN
# Q10_Part_10                     NaN     NaN    NaN
# Q10_Part_11                     NaN     NaN    NaN
# Q10_Part_12                     NaN     NaN    NaN
# Q10_Part_13                     NaN     NaN    NaN
# Q10_Part_14                     NaN     NaN    NaN
# Q10_Part_15                   147.0     NaN    NaN
# Q10_Part_16                     NaN  7174.0    NaN
# Q10_OTHER                       NaN     NaN  737.0

# %%
nombres_col = b.columns

# %%
dicc = {}

for col in b:
    suma = b[col].sum()
    dicc[col] = suma

# %%
dicc.keys()
# Out:
# dict_keys([' Kaggle Notebooks', 'Colab Notebooks', 'Azure Notebooks', ' Paperspace / Gradient ', ' Binder / JupyterHub ', ' Code Ocean ', ' IBM Watson Studio ', ' Amazon Sagemaker Studio Notebooks ', ' Amazon EMR Notebooks ', 'Google Cloud Notebooks (AI Platform / Vertex AI) ', 'Google Cloud Datalab', ' Databricks Collaborative Notebooks ', ' Zeppelin / Zepl Notebooks ', ' Deepnote Notebooks ', ' Observable Notebooks ', 'None', 'Other'])

# %%
personas_herramienta = pd.DataFrame([[key, dicc[key]] for key in dicc.keys()])
personas_herramienta
# Out:
#                                                     0       1
# 0                                    Kaggle Notebooks  9507.0
# 1                                     Colab Notebooks  9792.0
# 2                                     Azure Notebooks  1062.0
# 3                              Paperspace / Gradient    209.0
# 4                                Binder / JupyterHub   1770.0
# 5                                         Code Ocean    175.0
# 6                                  IBM Watson Studio   1067.0
# 7                  Amazon Sagemaker Studio Notebooks    753.0
# 8                               Amazon EMR Notebooks    348.0
# 9   Google Cloud Notebooks (AI Platform / Vertex AI)   2051.0
# 10                               Google Cloud Datalab  1794.0
# 11                Databricks Collaborative Notebooks    590.0
# 12                         Zeppelin / Zepl Notebooks    251.0
# 13                                Deepnote Notebooks    260.0
# 14                              Observable Notebooks    147.0
# 15                                               None  7174.0
# 16                                              Other   737.0

# %%
personas_herramienta = personas_herramienta.sort_values(by = [1], ascending = False)
personas_herramienta["porcentaje"] =  personas_herramienta[1].apply(lambda x: (x / df10.shape[0] * 100))
personas_herramienta
# Out:
#                                                     0       1  porcentaje
# 1                                     Colab Notebooks  9792.0   37.700689
# 0                                    Kaggle Notebooks  9507.0   36.603396
# 15                                               None  7174.0   27.620991
# 9   Google Cloud Notebooks (AI Platform / Vertex AI)   2051.0    7.896662
# 10                               Google Cloud Datalab  1794.0    6.907173
# 4                                Binder / JupyterHub   1770.0    6.814769
# 6                                  IBM Watson Studio   1067.0    4.108112
# 2                                     Azure Notebooks  1062.0    4.088862
# 7                  Amazon Sagemaker Studio Notebooks    753.0    2.899165
# 16                                              Other   737.0    2.837562
# 11                Databricks Collaborative Notebooks    590.0    2.271590
# 8                               Amazon EMR Notebooks    348.0    1.339853
# 13                                Deepnote Notebooks    260.0    1.001040
# 12                         Zeppelin / Zepl Notebooks    251.0    0.966388
# 3                              Paperspace / Gradient    209.0    0.804682
# 5                                         Code Ocean    175.0    0.673777
# 14                              Observable Notebooks    147.0    0.565972

# %%
herramientas = personas_herramienta[0]
herramientas
# Out:
# 1                                       Colab Notebooks
# 0                                      Kaggle Notebooks
# 15                                                 None
# 9     Google Cloud Notebooks (AI Platform / Vertex AI)
# 10                                 Google Cloud Datalab
# 4                                  Binder / JupyterHub
# 6                                    IBM Watson Studio
# 2                                       Azure Notebooks
# 7                    Amazon Sagemaker Studio Notebooks
# 16                                                Other
# 11                  Databricks Collaborative Notebooks
# 8                                 Amazon EMR Notebooks
# 13                                  Deepnote Notebooks
# 12                           Zeppelin / Zepl Notebooks
# 3                                Paperspace / Gradient
# 5                                           Code Ocean
# 14                                Observable Notebooks
# Name: 0, dtype: object

# %%
personas_herramienta = personas_herramienta.rename(columns={0:"nombre", 1: "numero", "porcentaje": "porcentaje"})
personas_herramienta.index
# Out:
# Int64Index([1, 0, 15, 9, 10, 4, 6, 2, 7, 16, 11, 8, 13, 12, 3, 5, 14], dtype='int64')

# %%
a= personas_herramienta.reindex(index = [1, 0, 9, 10, 4, 6, 2, 7, 11, 8, 13, 12, 3, 5, 14, 16, 15])

# %%
plt.figure(figsize =(10, 10))

fig = sns.catplot(y='nombre', x = "porcentaje", data = a, kind = "bar", aspect=2)

fig.set(xlabel = "Porcentaje de personas encuestadas", ylabel = "Principales herramientas")


plt.title('¿Cuáles son las herramientas más utilizadas?', fontsize=20)

plt.show()

# %%
plt.title('¿Cuáles son las herramientas más utilizadas?', fontsize=20)

fig = sns.catplot(y= '0' , x ='porcentaje', data = personas_herramienta, kind = "bar", aspect=2)

fig.set(xlabel = "Porcentaje de las personas encuestadas", ylabel = "Principales herramientas")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12033/1982564495.py in <module>
#       1 plt.title('¿Cuáles son las herramientas más utilizadas?', fontsize=20)
#       2
# ----> 3 fig = sns.catplot(y= '0' , x ='porcentaje', data = personas_herramienta, kind = "bar", aspect=2)
#       4
#       5 fig.set(xlabel = "Porcentaje de las personas encuestadas", ylabel = "Principales herramientas")
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# -> 3792     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793     if (
#    3794         order is not None
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input '0'
