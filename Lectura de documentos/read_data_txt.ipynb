# %%
#Cargo el archivo txt

import pandas as pd
import numpy as np

df = pd.read_csv("data_txt_clean.txt", sep = ';')

# %%
#inspecciono el txt

shape = df.shape
print(shape)
# Out:
# (25973, 27)

# %%
df.head()
#Creo que la columna index se puede eliminar, el archivo esta todo en ingles
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#        Q8                                                Q11  \
# 0  Python                                           A laptop
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2  Python                                           A laptop
# 3  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0           2-5 times                             5-10 years
# ...

# %%
columns= df.columns # Las Q estan en desorden faltan Q10, Q18, Q19, Q27, Q28, Q29, Q30, Q31, Q36,Q37,Q38,Q39 y Q40
print(columns)
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q15', 'Q20',
#        'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9',
#        'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object')

# %%
data_type= df.dtypes
print(data_type)
#Todas las columnas son de string no hay números
# Out:
# index     int64
# Q3       object
# Q4       object
# Q5       object
# Q6       object
# Q8       object
# Q11      object
# Q13      object
# Q15      object
# Q20      object
# Q21      object
# Q22      object
# Q23      object
# Q25      object
# Q26      object
# Q33      object
# Q35      object
# Q41      object
# Q7       object
# Q9       object
# Q12      object
# Q14      object
# Q16      object
# Q17      object
# Q24      object
# Q32      object
# Q34      object
# dtype: object

# %%
total_null = df.isnull().sum()
print(total_null)
# Out:
# index        0
# Q3           0
# Q4           0
# Q5           0
# Q6           0
# Q8        1033
# Q11       1253
# Q13       1570
# Q15       2219
# Q20       9648
# Q21       9722
# Q22       9847
# Q23      10021
# Q25      10582
# Q26      10790
# Q33      21317
# Q35      23736
# Q41       7484
# Q7        1032
# Q9        1039
# Q12       1391
# Q14       2003
# Q16       6349
# Q17       6658
# Q24      10338
# Q32      16489
# Q34      16574
# dtype: int64

# %%
df.isna().sum()
# Out:
# index        0
# Q3           0
# Q4           0
# Q5           0
# Q6           0
# Q8        1033
# Q11       1253
# Q13       1570
# Q15       2219
# Q20       9648
# Q21       9722
# Q22       9847
# Q23      10021
# Q25      10582
# Q26      10790
# Q33      21317
# Q35      23736
# Q41       7484
# Q7        1032
# Q9        1039
# Q12       1391
# Q14       2003
# Q16       6349
# Q17       6658
# Q24      10338
# Q32      16489
# Q34      16574
# dtype: int64

# %%
df.describe(include = "object").T
# Out:
#      count unique                                                top   freq
# Q3   25973     66                                              India   7434
# Q4   25973      7                                    Master’s degree  10132
# Q5   25973     15                                            Student   6804
# Q6   25973      7                                          1-3 years   7874
# Q8   24940     13                                             Python  20213
# Q11  24720      6                                           A laptop  16231
# Q13  24403      5                                              Never  16457
# Q15  23754      9                                           < 1 year   9163
# Q20  16325     18                               Computers/Technology   4079
# Q21  16251      5                                     0-49 employees   5055
# Q22  16126      7                                                1-2   3642
# ...

# %%
def propiedades (df):
    a = ("El número de filas y columnas es: ", df.shape) 
    b = ("Las columnas son: ", df.columns)
    c = ("El tipo de datos es: ", df.dtypes)
    d = ("Cantidad de nulos: ",df.isna().sum()) 
    e = ("Descripción general: ", df.describe(include = "object").T)
    f = ("Las primeras filas son: ", df.head())
    
    print(a, "\n", b, "\n", c, "\n", d, "\n", e,  "\n", f,)
    
propiedades(df)
# Out:
# ('El número de filas y columnas es: ', (25973, 27))
#  ('Las columnas son: ', Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q15', 'Q20',
#        'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9',
#        'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object'))
#  ('El tipo de datos es: ', index     int64
# Q3       object
# Q4       object
# Q5       object
# Q6       object
# Q8       object
# Q11      object
# Q13      object
# Q15      object
# Q20      object
# Q21      object
# Q22      object
# Q23      object
# Q25      object
# Q26      object
# Q33      object
# Q35      object
# Q41      object
# Q7       object
# Q9       object
# Q12      object
# Q14      object
# Q16      object
# Q17      object
# Q24      object
# Q32      object
# Q34      object
# dtype: object)
#  ('Cantidad de nulos: ', index        0
# Q3           0
# Q4           0
# Q5           0
# Q6           0
# Q8        1033
# Q11       1253
# ...
