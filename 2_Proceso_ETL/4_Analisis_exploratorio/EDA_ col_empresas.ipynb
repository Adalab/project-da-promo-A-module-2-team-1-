# %% [markdown]
# # Analisis Exploratorio
#     COLUMNAS
#     -'role'
#     -'salary'
#     -'industry'
#     -'company size'
#     -'people_in_data'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sidetable as stb
from sklearn.preprocessing import OneHotEncoder
import re 
import warnings

# %%
df = pd.read_csv("/mnt/c/Users/USUARIO/Desktop/Adalab/project-da-promo-A-module-2-team-1-/Limpieza de documentos/preparadito.csv", index_col= 0)

# %% [markdown]
# verificamos que los index esten bien.

# %%
df.head(3)
# Out:
#    survey_number    age gender    country    education_level  \
# 0            910  50-54    Man      India  Bachelor’s degree
# 1            784  50-54    Man  Indonesia    Master’s degree
# 2            924  22-24    Man   Pakistan    Master’s degree
#
#   programming_experience programming_language  \
# 0             5-10 years            Python, R
# 1              20+ years    SQL, C, C++, Java
# 2              1-3 years    Python, C++, Java
#
#                                      primary_bd_tool  \
# 0  Local development environments (RStudio, Jupyt...
# 1    Advanced statistical software (SPSS, SAS, etc.)
# 2  Basic statistical software (Microsoft Excel, G...
#
#                                 years_ml                      ml_frameworks  \
# 0                             5-10 years  Scikit-learn , TensorFlow ,Caret
# 1                               < 1 year                      Scikit-learn
# 2  I do not use machine learning methods                                NaN
#
#                                        ml_algorithms                     role  \
# 0  Linear or Logistic Regression, Decision Trees ...                    Other
# 1  Linear or Logistic Regression, Decision Trees ...  Program/Project Manager
# 2                                                NaN        Software Engineer
#
#           salary                   industry          company_size  \
# 0  25,000-29,999  Manufacturing/Fabrication      50-249 employees
# 1  60,000-69,999  Manufacturing/Fabrication  1000-9,999 employees
# 2         $0-999        Academics/Education  1000-9,999 employees
#
#   people_in_data gender_2
# 0            3-4      Man
# 1            1-2      Man
# 2              0      Man

# %%
df.tail(3)
# Out:
#        survey_number    age gender                   country  \
# 25970            494  50-54    Man                    Sweden
# 25971            277  45-49    Man  United States of America
# 25972            255  18-21    Man                     India
#
#          education_level     programming_experience programming_language  \
# 25970    Doctoral degree  I have never written code                  NaN
# 25971    Master’s degree                 5-10 years          Python, SQL
# 25972  Bachelor’s degree  I have never written code                  NaN
#
#                                          primary_bd_tool   years_ml  \
# 25970  Basic statistical software (Microsoft Excel, G...        NaN
# 25971                                                NaN  4-5 years
# 25972    Advanced statistical software (SPSS, SAS, etc.)        NaN
#
#        ml_frameworks                                      ml_algorithms  \
# 25970            NaN                                                NaN
# 25971  Scikit-learn   Linear or Logistic Regression, Decision Trees ...
# 25972            NaN                                                NaN
#
#                      role  salary                                industry  \
# 25970  Research Scientist  $0-999                     Academics/Education
# 25971      Data Scientist     NaN  Online Service/Internet-based Services
# 25972    Business Analyst  $0-999                                   Other
#
#                    company_size people_in_data gender_2
# 25970      1000-9,999 employees            20+      Man
# 25971  10,000 or more employees            20+      Man
# 25972            0-49 employees              0      Man

# %%
df.shape
# Out:
# (25973, 17)

# %% [markdown]
# Analizamos que tipo de datos tenemos

# %%
df.dtypes
# Out:
# survey_number              int64
# age                       object
# gender                    object
# country                   object
# education_level           object
# programming_experience    object
# programming_language      object
# primary_bd_tool           object
# years_ml                  object
# ml_frameworks             object
# ml_algorithms             object
# role                      object
# salary                    object
# industry                  object
# company_size              object
# people_in_data            object
# gender_2                  object
# dtype: object

# %%
df.describe().T
# Out:
#                  count          mean            std    min    25%    50%  \
# survey_number  25973.0  11054.664921  101471.622125  120.0  443.0  656.0
#
#                   75%        max
# survey_number  1038.0  2488653.0

# %%
df.describe(include = ['O']).T
# Out:
#                         count unique  \
# age                     25973     11
# gender                  25973      5
# country                 25973     66
# education_level         25973      7
# programming_experience  25973      7
# programming_language    24941    825
# primary_bd_tool         18489      6
# years_ml                23754      9
# ml_frameworks           19624   1401
# ml_algorithms           19315    756
# role                    25973     15
# salary                  15391     26
# industry                16325     18
# company_size            16251      5
# people_in_data          16126      7
# gender_2                25973      3
#
#                                                                       top  \
# age                                                                 25-29
# gender                                                                Man
# country                                                             India
# education_level                                           Master’s degree
# programming_experience                                          1-3 years
# programming_language                                               Python
# primary_bd_tool         Basic statistical software (Microsoft Excel, G...
# years_ml                                                         < 1 year
# ml_frameworks                                               Scikit-learn
# ml_algorithms           Linear or Logistic Regression, Decision Trees ...
# role                                                              Student
# salary                                                             $0-999
# industry                                             Computers/Technology
# company_size                                               0-49 employees
# people_in_data                                                        1-2
# gender_2                                                              Man
#
#                          freq
# age                      4931
# gender                  20598
# country                  7434
# education_level         10132
# programming_experience   7874
# programming_language     4740
# primary_bd_tool          7246
# years_ml                 9163
# ml_frameworks            2688
# ml_algorithms            1807
# role                     6804
# salary                   3369
# industry                 4079
# company_size             5055
# people_in_data           3642
# gender_2                20598

# %% [markdown]
# Revisamos los nulos que tenemos

# %%
df.isnull().sum()
# Out:
# survey_number                 0
# age                           0
# gender                        0
# country                       0
# education_level               0
# programming_experience        0
# programming_language       1032
# primary_bd_tool            7484
# years_ml                   2219
# ml_frameworks              6349
# ml_algorithms              6658
# role                          0
# salary                    10582
# industry                   9648
# company_size               9722
# people_in_data             9847
# gender_2                      0
# dtype: int64

# %% [markdown]
# Revisar duplicados

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# Encontramos el duplicado

# %%
df.loc[df.duplicated(), :]
# Out:
#        survey_number    age gender country    education_level  \
# 24480            297  18-21    Man   India  Bachelor’s degree
#
#       programming_experience programming_language primary_bd_tool  \
# 24480              < 1 years       Python, C, C++             NaN
#
#                                     years_ml ml_frameworks ml_algorithms  \
# 24480  I do not use machine learning methods           NaN           NaN
#
#           role salary industry company_size people_in_data gender_2
# 24480  Student    NaN      NaN          NaN            NaN      Man

# %%
df.loc[[24480]]
# Out:
#        survey_number    age gender country    education_level  \
# 24480            297  18-21    Man   India  Bachelor’s degree
#
#       programming_experience programming_language primary_bd_tool  \
# 24480              < 1 years       Python, C, C++             NaN
#
#                                     years_ml ml_frameworks ml_algorithms  \
# 24480  I do not use machine learning methods           NaN           NaN
#
#           role salary industry company_size people_in_data gender_2
# 24480  Student    NaN      NaN          NaN            NaN      Man

# %% [markdown]
# eliminamos el duplicado

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Revisar valores únicos

# %%
df.role.unique()
# Out:
# array(['Other', 'Program/Project Manager', 'Software Engineer',
#        'Research Scientist', 'Currently not employed', 'Student',
#        'Data Scientist', 'Data Analyst', 'Machine Learning Engineer',
#        'Business Analyst', 'Data Engineer', 'Product Manager',
#        'Statistician', 'Developer Relations/Advocacy',
#        'DBA/Database Engineer'], dtype=object)

# %%
plt.rcParams["figure.figsize"] = (10,10)
warnings.filterwarnings('ignore')

# %%
large_to_small= df.groupby('role').size().sort_values().index[::-1]

# %%
ax = sns.countplot(y="role", order= large_to_small, data=df)

# %% [markdown]
#     Role no tiene nulos ni errores en valores únicos. No necesitamos hacer cambios

# %%
df.salary.unique()
# Out:
# array(['25,000-29,999', '60,000-69,999', '$0-999', '30,000-39,999', nan,
#        '15,000-19,999', '70,000-79,999', '2,000-2,999', '10,000-14,999',
#        '5,000-7,499', '20,000-24,999', '1,000-1,999', '100,000-124,999',
#        '7,500-9,999', '4,000-4,999', '40,000-49,999', '50,000-59,999',
#        '3,000-3,999', '300,000-499,999', '200,000-249,999',
#        '125,000-149,999', '250,000-299,999', '80,000-89,999',
#        '90,000-99,999', '150,000-199,999', '>$1,000,000',
#        '$500,000-999,999'], dtype=object)

# %%
df.salary.value_counts()
# Out:
# $0-999              3369
# 1,000-1,999          969
# 10,000-14,999        950
# 30,000-39,999        741
# 100,000-124,999      725
# 5,000-7,499          699
# 50,000-59,999        697
# 40,000-49,999        688
# 20,000-24,999        587
# 2,000-2,999          575
# 15,000-19,999        573
# 7,500-9,999          552
# 60,000-69,999        551
# 25,000-29,999        470
# 70,000-79,999        464
# 4,000-4,999          456
# 150,000-199,999      392
# 80,000-89,999        391
# 3,000-3,999          380
# 125,000-149,999      379
# 90,000-99,999        350
# 200,000-249,999      177
# 300,000-499,999       91
# 250,000-299,999       75
# >$1,000,000           58
# $500,000-999,999      32
# Name: salary, dtype: int64

# %% [markdown]
#     La columna salario tiene el simbolo $ en algunos valores, decidimos quitar este signo

# %%
df["salary_clean"] = df["salary"].str.replace("$","")

# %%
df.salary_clean.value_counts()
# Out:
# 0-999              3369
# 1,000-1,999         969
# 10,000-14,999       950
# 30,000-39,999       741
# 100,000-124,999     725
# 5,000-7,499         699
# 50,000-59,999       697
# 40,000-49,999       688
# 20,000-24,999       587
# 2,000-2,999         575
# 15,000-19,999       573
# 7,500-9,999         552
# 60,000-69,999       551
# 25,000-29,999       470
# 70,000-79,999       464
# 4,000-4,999         456
# 150,000-199,999     392
# 80,000-89,999       391
# 3,000-3,999         380
# 125,000-149,999     379
# 90,000-99,999       350
# 200,000-249,999     177
# 300,000-499,999      91
# 250,000-299,999      75
# >1,000,000           58
# 500,000-999,999      32
# Name: salary_clean, dtype: int64

# %% [markdown]
#     tenemos otra opción donde remplazamos los nan por unspecified

# %%
df['salary_clean'] = df['salary_clean'].replace(np.nan, "Unspecified")

# %% [markdown]
#     # Aca dejamos la gráfica con los nan convertidos en Unspecified

# %%
large_to_small= df.groupby('salary_clean').size().sort_values().index[::-1]

# %%
salary_order= '0-999', '1,000-1,999', '2,000-2,999', '3,000-3,999','4,000-4,999','5,000-7,499', '7,500-9,999','10,000-14,999','15,000-19,999','20,000-24,999', "25,000-29,999",'30,000-39,999','40,000-49,999', '50,000-59,999','60,000-69,999', '70,000-79,999','80,000-89,999','90,000-99,999', '100,000-124,999','125,000-149,999','150,000-199,999','200,000-249,999','250,000-299,999','300,000-499,999','500,000-999,999', '>1,000,000'

# %%
ax = sns.countplot(y="salary_clean", data=df, order= salary_order)

# %% [markdown]
#     # Aca dejamos la gráfica sin los nan convertidos en Unspecified

# %%
ax = sns.countplot(y="salary_clean", data=df, order= salary_order)

# %%
ax = sns.countplot(y="salary_clean", data=df, hue= "gender_2", order= salary_order)

# %% [markdown]
# salarios por género

# %% [markdown]
#     SALARIO
#     Algunos datos tenian el simbolo $. Hemos creado una nueva columna, donde eliminamos el $ de los valores. Los valores nulos los convertimos en sin especificar en el df orginal y los eliminamos en el df copia

# %%
df.industry.value_counts()

# %%
df.industry.isnull().sum()
# Out:
# 9647

# %%
large_to_small= df.groupby('industry').size().sort_values().index[::-1]

# %%
ax = sns.countplot(y="industry", data=df, order= large_to_small)

# %%
df['industry_clean'] = df['industry'].replace(np.nan, "Unspecified")

# %%
large_to_small= df.groupby('industry_clean').size().sort_values().index[::-1]

# %%
ax = sns.countplot(y="industry_clean", data=df, order= large_to_small)

# %% [markdown]
#     La columna industry tiene valores nulos, que reemplazamos por Unspecified

# %%
df["company_size"].unique()
# Out:
# array(['50-249 employees', '1000-9,999 employees', nan,
#        '10,000 or more employees', '0-49 employees', '250-999 employees'],
#       dtype=object)

# %%
df.company_size.isnull().sum()
# Out:
# 9721

# %% [markdown]
# Acá he puesto la variable large to small con el codigo para ordenar según la cantidad

# %%
large_to_small= df.groupby('company_size').size().sort_values().index[::-1]
ax = sns.countplot(y="company_size", data=df, order= large_to_small)

# %%
df['company_size_clean'] = df['company_size'].replace(np.nan, "Unspecified")

# %%
large_to_small= df.groupby('company_size_clean').size().sort_values().index[::-1]
ax = sns.countplot(y="company_size_clean", data=df, order= large_to_small)

# %% [markdown]
#     Los valores nulos de la columna company size los dejamos con Unspecified

# %%
df.people_in_data.unique()
# Out:
# array(['3-4', '1-2', '0', '5-9', nan, '10-14', '20+', '15-19'],
#       dtype=object)

# %%
df.people_in_data.value_counts()
# Out:
# 1-2      3642
# 20+      3595
# 0        3064
# 3-4      2558
# 5-9      1850
# 10-14     996
# 15-19     421
# Name: people_in_data, dtype: int64

# %%
df.people_in_data.isnull().sum()
# Out:
# 9846

# %%
df.people_in_data.unique()
# Out:
# array(['3-4', '1-2', '0', '5-9', nan, '10-14', '20+', '15-19'],
#       dtype=object)

# %%
pd_order= '0', '1-2', '3-4', '5-9', '10-14','15-19', '20+'

# %%
ax = sns.countplot(y="people_in_data", data=df, order= pd_order)

# %%
df['people_in_data_clean'] = df['people_in_data'].replace(np.nan, "Unspecified")

# %%
pd_order= "Unspecified",'0', '1-2', '3-4', '5-9', '10-14','15-19', '20+'

# %%
ax = sns.countplot(y="people_in_data_clean", data=df, order= pd_order)

# %% [markdown]
#     Reemplazamos los valores nulos de la columna People in data por Unspecified, suena un poco raro 0 personas in data, podriamos cambiar el nombre de 0 por sin equipo.

# %%
df.to_csv("analisis_exploratorio_col_empresas.csv")

# %% [markdown]
# # CREAMOS UN DATA FRAME SOLO DE MUJERES Y OTRO SOLO DE HOMBRES PARA HACER COMPARACIONES

# %%
df_copia= df.copy()

# %%
df_copia.salary_clean.isnull().sum()
# Out:
# 0

# %%
df_copia.dropna(how='all')
df_copia.dropna(inplace=True)

# %%
df_mujeres= df[df["gender_2"].isin(["Woman"])]

# %%
df_hombres= df[df["gender_2"].isin(["Man"])]

# %% [markdown]
# Creamos un DATA FRAME solo para analistas

# %%
df_analistas= df[df["role"].isin(["Data Analyst"])]

# %%
large_to_small= df_mujeres.groupby('industry').size().sort_values().index[::-1]
plt.figure(figsize =(8,12)) 
fig = sns.countplot(y= "industry", order= large_to_small, data = df_mujeres) 
fig.legend(loc="upper right")
fig.set_title('WOMAN')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
large_to_small= df_hombres.groupby('industry').size().sort_values().index[::-1]
plt.figure(figsize =(8,12)) 
fig = sns.countplot(y= "industry", order= large_to_small, data = df_hombres,palette= "muted") 
fig.legend(loc="upper right")
fig.set_title('MEN')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Comparación en Role

# %%
large_to_small= df_mujeres.groupby('role').size().sort_values().index[::-1]
plt.figure(figsize =(7,11)) 
fig = sns.countplot(y= "role", order= large_to_small, data = df_mujeres) 
fig.legend(loc="upper right")
fig.set_title('WOMEN')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
large_to_small= df_hombres.groupby('role').size().sort_values().index[::-1]
plt.figure(figsize =(7,11)) 
fig = sns.countplot(y= "role", order= large_to_small, data = df_hombres, palette= "muted") 
fig.legend(loc="upper right")
fig.set_title('MEN')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Comparacion en Salario

# %%
df_mujeres_sin_nan= df_copia[df_copia["gender_2"].isin(["Woman"])]

# %%
df_hombres_sin_nan= df_copia[df_copia["gender_2"].isin(["Man"])]

# %%
salary_order= '0-999', '1,000-1,999', '2,000-2,999', '3,000-3,999','4,000-4,999','5,000-7,499', '7,500-9,999','10,000-14,999','15,000-19,999','20,000-24,999', "25,000-29,999",'30,000-39,999','40,000-49,999', '50,000-59,999','60,000-69,999', '70,000-79,999','80,000-89,999','90,000-99,999', '100,000-124,999','125,000-149,999','150,000-199,999','200,000-249,999','250,000-299,999','300,000-499,999','500,000-999,999', '>1,000,000'

# %%
plt.figure(figsize =(10,12)) 
fig = sns.countplot(y= "salary_clean", order= salary_order, data = df_hombres_sin_nan, palette= "muted") 
fig.set_title('MEN')
plt.show()

# %%
plt.figure(figsize =(10,12)) 
fig = sns.countplot(y= "salary_clean", order= salary_order, data = df_mujeres_sin_nan, palette= "pastel" ) 
fig.legend(loc="upper right")
fig.set_title('WOMEN')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = sns.countplot(y="people_in_data", data=df_mujeres, order= pd_order, palette= "pastel" )
fig.set_title('WOMEN')
# Out:
# Text(0.5, 1.0, 'WOMEN')

# %%
fig = sns.countplot(y="people_in_data", data=df_hombres, order= pd_order,  palette= "muted")
fig.set_title('MEN')
# Out:
# Text(0.5, 1.0, 'MEN')

# %%
company_size_order= '0-49 employees','50-249 employees','250-999 employees','1000-9,999 employees','10,000 or more employees'

# %%
plt.figure(figsize =(10,12)) 
fig = sns.countplot(y= "company_size", data = df_hombres, order= company_size_order, palette= "muted") 
fig.set_title('MEN')
plt.show()

# %%
plt.figure(figsize =(10,12)) 
fig = sns.countplot(y= "company_size", data = df_mujeres, order= company_size_order, palette= "pastel" ) 
fig.legend(loc="upper right")
fig.set_title('WOMEN')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
