# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#                                      Q15                        Q20  \
# 0                             5-10 years  Manufacturing/Fabrication
# 1                               < 1 year  Manufacturing/Fabrication
# 2  I do not use machine learning methods        Academics/Education
# 3                             5-10 years        Academics/Education
# 4                            10-20 years        Academics/Education
#
#                     Q21  Q22            Q25     Q33  Q35  \
# ...

# %%
df = pd.read_csv('csv_junto_sucio.csv', index_col= 0)
df.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#        Q8                                                Q11  \
# 0  Python                                           A laptop
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2  Python                                           A laptop
# 3  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0           2-5 times                             5-10 years
# ...

# %%
df.drop(['Q8', 'Q9', 'Q11', 'Q12', 'Q13', 'Q14', 'Q23', 'Q24', 'Q26'], axis=1, inplace=True)
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q15', 'Q20', 'Q21', 'Q22', 'Q25',
#        'Q33', 'Q35', 'Q41', 'Q7', 'Q16', 'Q17', 'Q32', 'Q34', 'Q10_Part_1',
#        'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5', 'Q10_Part_6',
#        'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10', 'Q10_Part_11',
#        'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14', 'Q10_Part_15',
#        'Q10_Part_16', 'Q10_OTHER', 'registro', 'edad', 'sexo'],
#       dtype='object')

# %%
df.drop(['Q32', 'Q34', 'Q10_Part_1',
       'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5', 'Q10_Part_6',
       'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10', 'Q10_Part_11',
       'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14', 'Q10_Part_15',
       'Q10_Part_16', 'Q10_OTHER'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q15', 'Q20', 'Q21', 'Q22', 'Q25',
#        'Q33', 'Q35', 'Q41', 'Q7', 'Q16', 'Q17', 'registro', 'edad', 'sexo'],
#       dtype='object')

# %%
df.drop(['Q33', 'Q35'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#                                      Q15                        Q20  \
# 0                             5-10 years  Manufacturing/Fabrication
# 1                               < 1 year  Manufacturing/Fabrication
# 2  I do not use machine learning methods        Academics/Education
# 3                             5-10 years        Academics/Education
# 4                            10-20 years        Academics/Education
#
#                     Q21  Q22            Q25  \
# 0      50-249 employees  3-4  25,000-29,999
# ...

# %%
df.rename(columns={'Q3': 'country', 'Q4': 'education_level','Q5': 'role', 'Q6': 'programming_experience', 'Q7':'programming_language', 'Q15': 'years_ml', 'Q16':'ml_frameworks', 'Q17':'ml_algorithms', 'Q20':'industry', 'Q21':'company_size', 'Q22': 'people_in_data', 'Q25': 'salary', 'Q41':'primary_bd_tool'}, inplace=True)

# %%
df.head()
# Out:
#    index    country    education_level                     role  \
# 0      0      India  Bachelor’s degree                    Other
# 1      1  Indonesia    Master’s degree  Program/Project Manager
# 2      2   Pakistan    Master’s degree        Software Engineer
# 3      3     Mexico    Doctoral degree       Research Scientist
# 4      4      India    Doctoral degree                    Other
#
#   programming_experience                               years_ml  \
# 0             5-10 years                             5-10 years
# 1              20+ years                               < 1 year
# 2              1-3 years  I do not use machine learning methods
# 3              20+ years                             5-10 years
# 4              < 1 years                            10-20 years
#
#                     industry          company_size people_in_data  \
# 0  Manufacturing/Fabrication      50-249 employees            3-4
# ...

# %%
column_names = ['registro', 'edad', 'sexo', 'country', 'education_level', 'programming_experience', 'programming_language', 'primary_bd_tool', 'years_ml', 'ml_frameworks', 'ml_algorithms', 'role', 'salary', 'industry', 'company size', 'people_in_data']

# %%
df = df.reindex(columns = column_names)
df.head()
# Out:
#    registro   edad sexo    country    education_level programming_experience  \
# 0       910  50-54  Man      India  Bachelor’s degree             5-10 years
# 1       784  50-54  Man  Indonesia    Master’s degree              20+ years
# 2       924  22-24  Man   Pakistan    Master’s degree              1-3 years
# 3       575  45-49  Man     Mexico    Doctoral degree              20+ years
# 4       781  45-49  Man      India    Doctoral degree              < 1 years
#
#   programming_language                                    primary_bd_tool  \
# 0            Python, R  Local development environments (RStudio, Jupyt...
# 1    SQL, C, C++, Java    Advanced statistical software (SPSS, SAS, etc.)
# 2    Python, C++, Java  Basic statistical software (Microsoft Excel, G...
# 3               Python  Local development environments (RStudio, Jupyt...
# 4    Python, C, MATLAB  Local development environments (RStudio, Jupyt...
#
# ...

# %%
df.rename(columns={'registro':'survey_number', 'edad':'age', 'sexo':'gender'}, inplace=True)
df.head()
# Out:
#    survey_number    age gender    country    education_level  \
# 0            910  50-54    Man      India  Bachelor’s degree
# 1            784  50-54    Man  Indonesia    Master’s degree
# 2            924  22-24    Man   Pakistan    Master’s degree
# 3            575  45-49    Man     Mexico    Doctoral degree
# 4            781  45-49    Man      India    Doctoral degree
#
#   programming_experience programming_language  \
# 0             5-10 years            Python, R
# 1              20+ years    SQL, C, C++, Java
# 2              1-3 years    Python, C++, Java
# 3              20+ years               Python
# 4              < 1 years    Python, C, MATLAB
#
#                                      primary_bd_tool  \
# 0  Local development environments (RStudio, Jupyt...
# 1    Advanced statistical software (SPSS, SAS, etc.)
# 2  Basic statistical software (Microsoft Excel, G...
# 3  Local development environments (RStudio, Jupyt...
# ...

# %%
df.to_csv('preparadito.csv')
